# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"C:\Users\Prashant\Desktop\collegedata\Data\civilA.csv")

# %%
data.head()
# Out:
#   User full name              Email address  \
# 0    19241A0101     ruhaillone007@gmail.com
# 1     19241A0102      asaiteja883@gmail.com
# 2    19241A0103   barishettyshiva@gmail.com
# 3    19241A0104     varuntej.1704@gmail.com
# 4    19241A0105    vamshinayak460@gmail.com
#
#                                     Date  1  2  3  4  5  6  7  ...  41  42  \
# 0   Wednesday, 27 November 2019, 9:55 AM  1  1  1  1  1  1  4  ...   1   1
# 1  Wednesday, 27 November 2019, 10:06 AM  1  4  5  3  4  5  5  ...   4   4
# 2  Wednesday, 27 November 2019, 10:14 AM  4  4  4  4  4  5  3  ...   4   4
# 3   Wednesday, 27 November 2019, 9:58 AM  3  5  5  5  4  5  4  ...   2   3
# 4  Wednesday, 27 November 2019, 10:12 AM  4  4  4  4  3  4  5  ...   3   4
#
#    43  44  45  46  47  48  49  50
# 0   1   1   1   5   1   1   1   1
# 1   4   4   4   4   4   4   4   5
# 2   4   4   3   5   3   4   4   4
# 3   5   4   4   5   3   4   5   5
# 4   3   4   4   4   4   4   4   4
#
# [5 rows x 53 columns]

# %%
data=data.drop('Date',axis=1)

# %%
self_awareness = data.drop(['2','3','4','5','7','8','9','10','12','13','14','15','16','17','18','19','20','22','23'],axis=1)

# %%
self_awareness = self_awareness.drop(['24','25','27','29','30','32','33','34','35','37','38','39','40','42','43','44','45','47','48','49','50'],axis=1)

# %%
self_awareness.head()
# Out:
#   User full name              Email address  1  6  11  21  26  28  31  36  41  \
# 0    19241A0101     ruhaillone007@gmail.com  1  1   1   1   1   1   1   5   1
# 1     19241A0102      asaiteja883@gmail.com  1  5   4   4   3   5   4   3   4
# 2    19241A0103   barishettyshiva@gmail.com  4  5   5   4   4   5   4   4   4
# 3    19241A0104     varuntej.1704@gmail.com  3  5   2   2   1   4   4   4   2
# 4    19241A0105    vamshinayak460@gmail.com  4  4   5   3   4   4   4   2   3
#
#    46
# 0   5
# 1   4
# 2   5
# 3   5
# 4   4

# %%
self_awareness['Self_aware']=self_awareness['1']+self_awareness['6']+self_awareness['11']+self_awareness['21']+self_awareness['26']+self_awareness['28']+self_awareness['31']+self_awareness['36']+self_awareness['41']+self_awareness['46']

# %%
self_awareness
# Out:
#    User full name                    Email address  1  6  11  21  26  28  31  \
# 0     19241A0101           ruhaillone007@gmail.com  1  1   1   1   1   1   1
# 1      19241A0102            asaiteja883@gmail.com  1  5   4   4   3   5   4
# 2     19241A0103         barishettyshiva@gmail.com  4  5   5   4   4   5   4
# 3     19241A0104           varuntej.1704@gmail.com  3  5   2   2   1   4   4
# 4     19241A0105          vamshinayak460@gmail.com  4  4   5   3   4   4   4
# 5     19241A0107            praneethk243@gmail.com  5  5   5   2   4   5   2
# 6     19241A0108        rahulchiluka2511@gmail.com  4  5   5   5   3   3   5
# 7     19241A0110            ragneshdayya@gmail.com  3  4   4   3   4   5   3
# 8     19241A0111          manishgoud3255@gmail.com  3  5   4   4   5   4   5
# 9     19241A0112           saipriyaerram@gmail.com  1  5   5   2   5   1   5
# 10    19241A0114         saigorantala457@gmail.com  1  5   5   3   1   5   5
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(self_awareness.Self_aware)

# %%
import seaborn as sn

# %%
self_awareness['Self_aware'].plot(kind='bar',figsize=(15, 3))
plt.xlabel("Question Number")
# Out:
# Text(0.5, 0, 'Question Number')

# %% [markdown]
# # Managing_Emotions

# %%
me = data.drop(['1','3','4','5','6','8','9','10','11','13','14','15','16','18','19','20','21','23','24','25','26','28','29','30','31','33','34','35','36','38','39','40','41','43','44','45','46','48','49','50'],axis=1)

# %%
me.head()
# Out:
#   User full name              Email address  2  7  12  17  22  27  32  37  42  \
# 0    19241A0101     ruhaillone007@gmail.com  1  4   1   1   1   1   1   4   1
# 1     19241A0102      asaiteja883@gmail.com  4  5   3   2   3   4   4   4   4
# 2    19241A0103   barishettyshiva@gmail.com  4  3   4   1   4   4   4   2   4
# 3    19241A0104     varuntej.1704@gmail.com  5  4   1   3   1   2   4   5   3
# 4    19241A0105    vamshinayak460@gmail.com  4  5   2   2   4   4   4   3   4
#
#    47
# 0   1
# 1   4
# 2   3
# 3   3
# 4   4

# %%
me['ManagingEmotions'] = me['2']+ me['7']+me['12']+me['17']+me['22']+me['27']+me['32']+me['37']+me['42']+me['47']

# %%
me
# Out:
#    User full name                    Email address  2  7  12  17  22  27  32  \
# 0     19241A0101           ruhaillone007@gmail.com  1  4   1   1   1   1   1
# 1      19241A0102            asaiteja883@gmail.com  4  5   3   2   3   4   4
# 2     19241A0103         barishettyshiva@gmail.com  4  3   4   1   4   4   4
# 3     19241A0104           varuntej.1704@gmail.com  5  4   1   3   1   2   4
# 4     19241A0105          vamshinayak460@gmail.com  4  5   2   2   4   4   4
# 5     19241A0107            praneethk243@gmail.com  5  5   5   3   1   5   4
# 6     19241A0108        rahulchiluka2511@gmail.com  5  2   5   5   3   4   2
# 7     19241A0110            ragneshdayya@gmail.com  4  4   5   5   3   3   4
# 8     19241A0111          manishgoud3255@gmail.com  4  3   3   3   3   4   5
# 9     19241A0112           saipriyaerram@gmail.com  5  5   5   5   1   5   5
# 10    19241A0114         saigorantala457@gmail.com  4  1   1   5   4   5   5
# ...

# %%
me['ManagingEmotions'].plot(kind='bar',figsize=(10,2))
plt.xlabel('Questions')
# Out:
# Text(0.5, 0, 'Questions')

# %% [markdown]
# ### Motivating_One_Self

# %%
data.head(2) ## now making motivating_one_self table from complete data set
# Out:
#   User full name            Email address  1  2  3  4  5  6  7  8  ...  41  \
# 0    19241A0101   ruhaillone007@gmail.com  1  1  1  1  1  1  4  1  ...   1
# 1     19241A0102    asaiteja883@gmail.com  1  4  5  3  4  5  5  4  ...   4
#
#    42  43  44  45  46  47  48  49  50
# 0   1   1   1   1   5   1   1   1   1
# 1   4   4   4   4   4   4   4   4   5
#
# [2 rows x 52 columns]

# %%
ms=data.drop(['1','2','4','5','6','7','9','10','11','12','14','15','16','17','19','20','21','22','24','25','26','27','29','30','31','32','34','35','36'],axis=1)

# %%
ms = ms.drop(['37','39','40','41','42','44','45','46','47','50'],axis=1)

# %%
ms
# Out:
#    User full name                    Email address  3  8  13  18  23  28  33  \
# 0     19241A0101           ruhaillone007@gmail.com  1  1   1   1   1   1   2
# 1      19241A0102            asaiteja883@gmail.com  5  4   1   4   3   5   3
# 2     19241A0103         barishettyshiva@gmail.com  4  4   4   4   4   5   4
# 3     19241A0104           varuntej.1704@gmail.com  5  5   1   1   4   4   4
# 4     19241A0105          vamshinayak460@gmail.com  4  4   5   2   3   4   4
# 5     19241A0107            praneethk243@gmail.com  5  5   1   5   5   5   5
# 6     19241A0108        rahulchiluka2511@gmail.com  5  4   4   3   5   3   4
# 7     19241A0110            ragneshdayya@gmail.com  4  3   2   3   3   5   3
# 8     19241A0111          manishgoud3255@gmail.com  4  3   4   2   4   4   4
# 9     19241A0112           saipriyaerram@gmail.com  1  1   4   1   5   1   4
# 10    19241A0114         saigorantala457@gmail.com  1  1   1   1   3   5   1
# ...

# %%
ms['motivating_one_self']=ms['3']+ms['8']+ms['13']+ms['23']+ms['28']+ms['33']+ms['38']+ms['43']+ms['48']

# %%
ms.head(5)
# Out:
#   User full name              Email address  3  8  13  18  23  28  33  38  43  \
# 0    19241A0101     ruhaillone007@gmail.com  1  1   1   1   1   1   2   3   1
# 1     19241A0102      asaiteja883@gmail.com  5  4   1   4   3   5   3   4   4
# 2    19241A0103   barishettyshiva@gmail.com  4  4   4   4   4   5   4   4   4
# 3    19241A0104     varuntej.1704@gmail.com  5  5   1   1   4   4   4   5   5
# 4    19241A0105    vamshinayak460@gmail.com  4  4   5   2   3   4   4   2   3
#
#    48  49  motivating_one_self
# 0   1   1                   12
# 1   4   4                   33
# 2   4   4                   37
# 3   4   5                   37
# 4   4   4                   33

# %%
ms['motivating_one_self'].plot(kind='bar',figsize=(10,2))
plt.xlabel('Questions')
# Out:
# Text(0.5, 0, 'Questions')

# %%
empathy = data.drop(['1','2','3','5','6','7','8','10','11','12','13','15','16','17','18','20','21','22','23','25','26','27','28','30','31','32','33','35','36','37','38','40','41','42','43','45','46','47','48','50'],axis=1)

# %%
empathy
# Out:
#    User full name                    Email address  4  9  14  19  24  29  34  \
# 0     19241A0101           ruhaillone007@gmail.com  1  1   1   1   1   1   3
# 1      19241A0102            asaiteja883@gmail.com  3  3   4   4   4   4   4
# 2     19241A0103         barishettyshiva@gmail.com  4  4   4   4   4   4   4
# 3     19241A0104           varuntej.1704@gmail.com  5  4   3   4   4   5   2
# 4     19241A0105          vamshinayak460@gmail.com  4  3   4   4   3   4   4
# 5     19241A0107            praneethk243@gmail.com  5  5   5   5   5   4   5
# 6     19241A0108        rahulchiluka2511@gmail.com  2  4   5   4   4   4   4
# 7     19241A0110            ragneshdayya@gmail.com  2  3   2   3   4   5   4
# 8     19241A0111          manishgoud3255@gmail.com  4  4   5   4   3   5   5
# 9     19241A0112           saipriyaerram@gmail.com  5  5   5   5   5   5   5
# 10    19241A0114         saigorantala457@gmail.com  1  1   4   4   1   5   1
# ...

# %%
empathy['Empathy']=empathy['4']+empathy['9']+empathy['14']+empathy['19']+empathy['24']+empathy['29']+empathy['34']+empathy['39']+empathy['44']+empathy['49']

# %%
empathy
# Out:
#    User full name                    Email address  4  9  14  19  24  29  34  \
# 0     19241A0101           ruhaillone007@gmail.com  1  1   1   1   1   1   3
# 1      19241A0102            asaiteja883@gmail.com  3  3   4   4   4   4   4
# 2     19241A0103         barishettyshiva@gmail.com  4  4   4   4   4   4   4
# 3     19241A0104           varuntej.1704@gmail.com  5  4   3   4   4   5   2
# 4     19241A0105          vamshinayak460@gmail.com  4  3   4   4   3   4   4
# 5     19241A0107            praneethk243@gmail.com  5  5   5   5   5   4   5
# 6     19241A0108        rahulchiluka2511@gmail.com  2  4   5   4   4   4   4
# 7     19241A0110            ragneshdayya@gmail.com  2  3   2   3   4   5   4
# 8     19241A0111          manishgoud3255@gmail.com  4  4   5   4   3   5   5
# 9     19241A0112           saipriyaerram@gmail.com  5  5   5   5   5   5   5
# 10    19241A0114         saigorantala457@gmail.com  1  1   4   4   1   5   1
# ...

# %%
empathy['Empathy'].plot(kind='bar',figsize=(15,2),legend=True,color='green')
plt.xlabel('Questions')
plt.ylabel('Score')
# Out:
# Text(0, 0.5, 'Score')

# %%
import seaborn as sn
import numpy as np

# %%
import numpy as np
import matplotlib.pyplot as plt


empathy = pd.DataFrame([13, 38, 40, 41, 48, 49,41,35,43,42,28,48,35,45,37,49,43,36,40,46,41,37,46,43,36,33,43,41,27,41,42,46,38,41,26,37,42,39,38,39,34,40,43,41,30,41,39,35,50,36,35], columns=['Empathy'])

x = np.arange(len(empathy.index))
y = empathy['Empathy']
fig = plt.figure()
fig.set_figheight(4)
fig.set_figwidth(15)
mask1 = y <= 35
mask2 = y > 35

plt.bar(x[mask1], y[mask1], color = 'green')
plt.bar(x[mask2], y[mask2], color = 'yellow')
plt.xlabel("Questions")
plt.ylabel("Score")

plt.gca().legend(('score<35','score>35'))

plt.show()

# %% [markdown]
# ##### In Above graph Green represent students having Empathy  below 35 and yellow vice-versa

# %% [markdown]
# ### Social-Skills

# %%
# here i am making social-skill table from main table data

# %%
sk=data.drop(['1','2','3','4','6','7','8','9','11','12','13','14','16','17','18','19','21','22','23','24','26','27','28','29','31','32','33','34','36','37','38','39','41','42','43','44','46','47','48','49'],axis=1)

# %%
sk.head()
# Out:
#   User full name              Email address  5  10  15  20  25  30  35  40  \
# 0    19241A0101     ruhaillone007@gmail.com  1   5   1   1   1   1   4   1
# 1     19241A0102      asaiteja883@gmail.com  4   5   3   4   5   4   5   4
# 2    19241A0103   barishettyshiva@gmail.com  4   5   4   4   4   4   4   4
# 3    19241A0104     varuntej.1704@gmail.com  4   1   5   3   5   5   1   5
# 4    19241A0105    vamshinayak460@gmail.com  3   5   4   5   4   4   4   4
#
#    45  50
# 0   1   1
# 1   4   5
# 2   3   4
# 3   4   5
# 4   4   4

# %%
sk['social']=sk['5']+sk['10']+sk['15']+sk['20']+sk['25']+sk['30']+sk['35']+sk['40']+sk['45']+sk['50']

# %%
sk.head()
# Out:
#   User full name              Email address  5  10  15  20  25  30  35  40  \
# 0    19241A0101     ruhaillone007@gmail.com  1   5   1   1   1   1   4   1
# 1     19241A0102      asaiteja883@gmail.com  4   5   3   4   5   4   5   4
# 2    19241A0103   barishettyshiva@gmail.com  4   5   4   4   4   4   4   4
# 3    19241A0104     varuntej.1704@gmail.com  4   1   5   3   5   5   1   5
# 4    19241A0105    vamshinayak460@gmail.com  3   5   4   5   4   4   4   4
#
#    45  50  social
# 0   1   1      17
# 1   4   5      43
# 2   3   4      40
# 3   4   5      38
# 4   4   4      41

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
sk = pd.DataFrame(sk['social'], columns=['social'])

x = np.arange(len(sk.index))
y = sk['social']

mask1 = y <= 35
mask2 = y > 35
fig = plt.figure()
fig.set_figheight(4)
fig.set_figwidth(15)
plt.bar(x[mask1], y[mask1], color = 'red')
plt.bar(x[mask2], y[mask2], color = 'yellow')

plt.gca().legend(('score<35','score>35'))
plt.xlabel('Questions')
plt.ylabel('Score')
plt.show()

# %% [markdown]
# ### Merging All tables

# %%
data['self']=self_awareness['Self_aware']

# %%
data['emotions'] = me['ManagingEmotions']

# %%
data['motivating']= ms['motivating_one_self']

# %%
data['Empathy']=empathy['Empathy']

# %%
data['social'] = sk['social']

# %%
data
# Out:
#    User full name                    Email address  1  2  3  4  5  6  7  8  \
# 0     19241A0101           ruhaillone007@gmail.com  1  1  1  1  1  1  4  1
# 1      19241A0102            asaiteja883@gmail.com  1  4  5  3  4  5  5  4
# 2     19241A0103         barishettyshiva@gmail.com  4  4  4  4  4  5  3  4
# 3     19241A0104           varuntej.1704@gmail.com  3  5  5  5  4  5  4  5
# 4     19241A0105          vamshinayak460@gmail.com  4  4  4  4  3  4  5  4
# 5     19241A0107            praneethk243@gmail.com  5  5  5  5  5  5  5  5
# 6     19241A0108        rahulchiluka2511@gmail.com  4  5  5  2  4  5  2  4
# 7     19241A0110            ragneshdayya@gmail.com  3  4  4  2  4  4  4  3
# 8     19241A0111          manishgoud3255@gmail.com  3  4  4  4  4  5  3  3
# 9     19241A0112           saipriyaerram@gmail.com  1  5  1  5  2  5  5  1
# 10    19241A0114         saigorantala457@gmail.com  1  4  1  1  5  5  1  1
# ...

# %%
# finaly sending all data created to a csv file.
# note i created a empty csv file first called collg.csv and then performed this operation
df = pd.DataFrame(data)
df.to_csv("C:\\Users\\Prashant\\Desktop\\collg.csv")
